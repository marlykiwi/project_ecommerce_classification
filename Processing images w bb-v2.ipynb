# %%
import pandas as pd

# %%
df = pd.read_csv("images_w_bounding_box.csv")

# %%
df.head()
# Out:
#    prdtypecode  codes                                      img   x1   x2   y1  \
# 0           10      0  image_1263597046_product_3804725264.jpg  183  316  150
# 1         2280     18   image_1008141237_product_436067568.jpg  160  340  119
# 2           50      2    image_938777978_product_201115110.jpg   75  424   70
# 3         1280      7     image_457047496_product_50418756.jpg   84  416   57
# 4         2705     25   image_1077757786_product_278535884.jpg  161  338  100
#
#     y2
# 0  350
# 1  380
# 2  428
# 3  442
# 4  395

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import numpy as np

# %%
image_path = "image_train/"

plt.figure(figsize=(15,7))
for i in range(8):
    plt.subplot(2,4,i+1)
    img = cv2.imread(image_path+df.img[i])
    img_shape = img.shape
    img = cv2.resize(img,(224,224))
    plt.imshow(img[...,::-1])
    plt.title("image" + str(i+1))
    x1 = df.x1[i]/img_shape[1]*224
    x2 = df.x2[i]/img_shape[1]*224
    y1 = df.y1[i]/img_shape[0]*224
    y2 = df.y2[i]/img_shape[0]*224
    plt.plot([x1,x2,x2,x1,x1],[y1,y1,y2,y2,y1],"r")
    plt.axis("off")
plt.show()

# %%
df = df.drop("prdtypecode", axis = 1)
df.head()
# Out:
#    codes                                      img   x1   x2   y1   y2
# 0      0  image_1263597046_product_3804725264.jpg  183  316  150  350
# 1     18   image_1008141237_product_436067568.jpg  160  340  119  380
# 2      2    image_938777978_product_201115110.jpg   75  424   70  428
# 3      7     image_457047496_product_50418756.jpg   84  416   57  442
# 4     25   image_1077757786_product_278535884.jpg  161  338  100  395

# %%
#Images corresponding to painted paper are not detected by the bounding box
#Coordinates will be filled manually
#vals = [29955, 40000, 82267]

df.loc[29955,("x2", "y2")] = 500
df.loc[40000,("x2", "y2")] = 500
df.loc[82267,("x2", "y2")] = 500

# %%
print(df.shape)
df = df.drop(index=[37124, 52327, 79708, 80859])
print(df.shape)
# Out:
# (84916, 6)
# (84912, 6)

# %%
# There are some images that are empty, we'll get rid of those
to_delete = [37124, 52327, 79708, 80859]
for el in to_delete:
    df.loc[el,("x1", "x2", "y1", "y2")] = np.nan

print(df.shape)
df = df.dropna(axis = 0, how = 'all', subset = ["x1", "x2", "y1", "y2"])
df.shape

# %%
df.to_csv(r'img_w_filled_vals2.csv', index = False)

# %%
data = df

# %%
def load_data(data):
    img_list = []
    label_list = []
    for i, f in enumerate(data.values):
        img = cv2.imread("image_train/"+f[1])
        img = img[f[4]:f[5],f[2]:f[3]]
        img = cv2.resize(img,(224,224))
        img_list.append(img) 
        if i%100 == 0:
            print(i)        
    return np.array(img_list)

# %%
data.head()
# Out:
#    codes                                      img   x1   x2   y1   y2
# 0      0  image_1263597046_product_3804725264.jpg  183  316  150  350
# 1     18   image_1008141237_product_436067568.jpg  160  340  119  380
# 2      2    image_938777978_product_201115110.jpg   75  424   70  428
# 3      7     image_457047496_product_50418756.jpg   84  416   57  442
# 4     25   image_1077757786_product_278535884.jpg  161  338  100  395

# %%
X = load_data(data)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200

# %%
Y = data["codes"]

# %%
len(empty)

# %%
df[52327:52328]

# %%
X = load_data(img_data[29900:30000])
Y = img_data["codes"][29900:30000]
